# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
zeropoint = np.load('Run_030718/bolp_20p0_0_bt3.npz')
pert1 = np.load('Run_030718/bolp_20p0_um_0_bt.npz')
pert2 = np.load('Run_030718/bolp_20p0_um_0_bt2.npz')
pert3 = np.load('Run_030718/bolp_20p0_um_0_bt3.npz')

# %%
##ngal(1)+wp{6+9+14+19+24+29}+ggl{7+10+15+20+25+30}+vpf{7+10+15+20+25+30}+Pcic{10+15+25+40+55+70}
        #1: 0:7   7:14 14:21 21:31
        #2: 0:10 10:20 20:30 30:45
        #3: 0:15 15:30 30:45 45:70
        #4: 0:20 20:40 40:60 60:100
        #5: 0:25 25:50 50:75 75:130
        #6: 0:30 30:60 60:90 90:160

# %%
pert_func1 = np.concatenate((pert1['func_all_1'][:2000],pert2['func_all_1'][:2000],pert3['func_all_1'][:2000],\
pert1['func_all_1'][2000:4000],pert2['func_all_1'][2000:4000],pert3['func_all_1'][2000:4000],\
pert1['func_all_1'][4000:6000],pert2['func_all_1'][4000:6000],pert3['func_all_1'][4000:6000],\
pert1['func_all_1'][6000:8000],pert2['func_all_1'][6000:8000],pert3['func_all_1'][6000:8000],\
pert1['func_all_1'][8000:10000],pert2['func_all_1'][8000:10000],pert3['func_all_1'][8000:10000],\
pert1['func_all_1'][10000:12000],pert2['func_all_1'][10000:12000],pert3['func_all_1'][10000:12000],\
pert1['func_all_1'][12000:],pert2['func_all_1'][12000:],pert3['func_all_1'][12000:]))
pert_func2 = np.concatenate((pert1['func_all_2'][:2000],pert2['func_all_2'][:2000],pert3['func_all_2'][:2000],\
pert1['func_all_2'][2000:4000],pert2['func_all_2'][2000:4000],pert3['func_all_2'][2000:4000],\
pert1['func_all_2'][4000:6000],pert2['func_all_2'][4000:6000],pert3['func_all_2'][4000:6000],\
pert1['func_all_2'][6000:8000],pert2['func_all_2'][6000:8000],pert3['func_all_2'][6000:8000],\
pert1['func_all_2'][8000:10000],pert2['func_all_2'][8000:10000],pert3['func_all_2'][8000:10000],\
pert1['func_all_2'][10000:12000],pert2['func_all_2'][10000:12000],pert3['func_all_2'][10000:12000],\
pert1['func_all_2'][12000:],pert2['func_all_2'][12000:],pert3['func_all_2'][12000:]))
pert_func3 = np.concatenate((pert1['func_all_3'][:2000],pert2['func_all_3'][:2000],pert3['func_all_3'][:2000],\
pert1['func_all_3'][2000:4000],pert2['func_all_3'][2000:4000],pert3['func_all_3'][2000:4000],\
pert1['func_all_3'][4000:6000],pert2['func_all_3'][4000:6000],pert3['func_all_3'][4000:6000],\
pert1['func_all_3'][6000:8000],pert2['func_all_3'][6000:8000],pert3['func_all_3'][6000:8000],\
pert1['func_all_3'][8000:10000],pert2['func_all_3'][8000:10000],pert3['func_all_3'][8000:10000],\
pert1['func_all_3'][10000:12000],pert2['func_all_3'][10000:12000],pert3['func_all_3'][10000:12000],\
pert1['func_all_3'][12000:],pert2['func_all_3'][12000:],pert3['func_all_3'][12000:]))
pert_func4 = np.concatenate((pert1['func_all_4'][:2000],pert2['func_all_4'][:2000],pert3['func_all_4'][:2000],\
pert1['func_all_4'][2000:4000],pert2['func_all_4'][2000:4000],pert3['func_all_4'][2000:4000],\
pert1['func_all_4'][4000:6000],pert2['func_all_4'][4000:6000],pert3['func_all_4'][4000:6000],\
pert1['func_all_4'][6000:8000],pert2['func_all_4'][6000:8000],pert3['func_all_4'][6000:8000],\
pert1['func_all_4'][8000:10000],pert2['func_all_4'][8000:10000],pert3['func_all_4'][8000:10000],\
pert1['func_all_4'][10000:12000],pert2['func_all_4'][10000:12000],pert3['func_all_4'][10000:12000],\
pert1['func_all_4'][12000:],pert2['func_all_4'][12000:],pert3['func_all_4'][12000:]))
pert_func5 = np.concatenate((pert1['func_all_5'][:2000],pert2['func_all_5'][:2000],pert3['func_all_5'][:2000],\
pert1['func_all_5'][2000:4000],pert2['func_all_5'][2000:4000],pert3['func_all_5'][2000:4000],\
pert1['func_all_5'][4000:6000],pert2['func_all_5'][4000:6000],pert3['func_all_5'][4000:6000],\
pert1['func_all_5'][6000:8000],pert2['func_all_5'][6000:8000],pert3['func_all_5'][6000:8000],\
pert1['func_all_5'][8000:10000],pert2['func_all_5'][8000:10000],pert3['func_all_5'][8000:10000],\
pert1['func_all_5'][10000:12000],pert2['func_all_5'][10000:12000],pert3['func_all_5'][10000:12000],\
pert1['func_all_5'][12000:],pert2['func_all_5'][12000:],pert3['func_all_5'][12000:]))
pert_func6 = np.concatenate((pert1['func_all_6'][:2000],pert2['func_all_6'][:2000],pert3['func_all_6'][:2000],\
pert1['func_all_6'][2000:4000],pert2['func_all_6'][2000:4000],pert3['func_all_6'][2000:4000],\
pert1['func_all_6'][4000:6000],pert2['func_all_6'][4000:6000],pert3['func_all_6'][4000:6000],\
pert1['func_all_6'][6000:8000],pert2['func_all_6'][6000:8000],pert3['func_all_6'][6000:8000],\
pert1['func_all_6'][8000:10000],pert2['func_all_6'][8000:10000],pert3['func_all_6'][8000:10000],\
pert1['func_all_6'][10000:12000],pert2['func_all_6'][10000:12000],pert3['func_all_6'][10000:12000],\
pert1['func_all_6'][12000:],pert2['func_all_6'][12000:],pert3['func_all_6'][12000:]))

# %%
p_pert = np.concatenate((pert1['param'][:2000],pert2['param'][:2000],pert3['param'][:2000],\
pert1['param'][2000:4000],pert2['param'][2000:4000],pert3['param'][2000:4000],\
pert1['param'][4000:6000],pert2['param'][4000:6000],pert3['param'][4000:6000],\
pert1['param'][6000:8000],pert2['param'][6000:8000],pert3['param'][6000:8000],\
pert1['param'][8000:10000],pert2['param'][8000:10000],pert3['param'][8000:10000],\
pert1['param'][10000:12000],pert2['param'][10000:12000],pert3['param'][10000:12000],\
pert1['param'][12000:],pert2['param'][12000:],pert3['param'][12000:]))

# %%
wp7_0 = zeropoint['func_all_1'][:,0:7]
wp10_0 = zeropoint['func_all_2'][:,0:10]
wp15_0 = zeropoint['func_all_3'][:,0:15]
wp20_0 = zeropoint['func_all_4'][:,0:20]
wp25_0 = zeropoint['func_all_5'][:,0:25]
wp30_0 = zeropoint['func_all_6'][:,0:30]
###
ds7_0 = zeropoint['func_all_1'][:,7:14]
ds10_0 = zeropoint['func_all_2'][:,10:20]
ds15_0 = zeropoint['func_all_3'][:,15:30]
ds20_0 = zeropoint['func_all_4'][:,20:40]
ds25_0 = zeropoint['func_all_5'][:,25:50]
ds30_0 = zeropoint['func_all_6'][:,30:60]
###
vpf7_0 = zeropoint['func_all_1'][:,14:21]
vpf10_0 = zeropoint['func_all_2'][:,20:30]
vpf15_0 = zeropoint['func_all_3'][:,30:45]
vpf20_0 = zeropoint['func_all_4'][:,40:60]
vpf25_0 = zeropoint['func_all_5'][:,50:75]
vpf30_0 = zeropoint['func_all_6'][:,60:90]
###
cic10_0 = zeropoint['func_all_1'][:,21:]
cic15_0 = zeropoint['func_all_2'][:,30:]
cic25_0 = zeropoint['func_all_3'][:,45:]
cic40_0 = zeropoint['func_all_4'][:,60:]
cic55_0 = zeropoint['func_all_5'][:,75:]
cic70_0 = zeropoint['func_all_6'][:,90:]
###
wp7_p = pert_func1[:,0:7]
wp10_p = pert_func2[:,0:10]
wp15_p = pert_func3[:,0:15]
wp20_p = pert_func4[:,0:20]
wp25_p = pert_func5[:,0:25]
wp30_p = pert_func6[:,0:30]
###
ds7_p = pert_func1[:,7:14]
ds10_p = pert_func2[:,10:20]
ds15_p = pert_func3[:,15:30]
ds20_p = pert_func4[:,20:40]
ds25_p = pert_func5[:,25:50]
ds30_p = pert_func6[:,30:60]
###
vpf7_p = pert_func1[:,14:21]
vpf10_p = pert_func2[:,20:30]
vpf15_p = pert_func3[:,30:45]
vpf20_p = pert_func4[:,40:60]
vpf25_p = pert_func5[:,50:75]
vpf30_p = pert_func6[:,60:90]
###
cic10_p = pert_func1[:,21:]
cic15_p = pert_func2[:,30:]
cic25_p = pert_func3[:,45:]
cic40_p = pert_func4[:,60:]
cic55_p = pert_func5[:,75:]
cic70_p = pert_func6[:,90:]
###
wp7_covjk = zeropoint['func_all_cov_1'][:,0:7,0:7]
wp10_covjk = zeropoint['func_all_cov_2'][:,0:10,0:10]
wp15_covjk = zeropoint['func_all_cov_3'][:,0:15,0:15]
wp20_covjk = zeropoint['func_all_cov_4'][:,0:20,0:20]
wp25_covjk = zeropoint['func_all_cov_5'][:,0:25,0:25]
wp30_covjk = zeropoint['func_all_cov_6'][:,0:30,0:30]
###
ds7_covjk = zeropoint['func_all_cov_1'][:,7:14,7:14]
ds10_covjk = zeropoint['func_all_cov_2'][:,10:20,10:20]
ds15_covjk = zeropoint['func_all_cov_3'][:,15:30,15:30]
ds20_covjk = zeropoint['func_all_cov_4'][:,20:40,20:40]
ds25_covjk = zeropoint['func_all_cov_5'][:,25:50,25:50]
ds30_covjk = zeropoint['func_all_cov_6'][:,30:60,30:60]
###
vpf7_covjk = zeropoint['func_all_cov_1'][:,14:21,14:21]
vpf10_covjk = zeropoint['func_all_cov_2'][:,20:30,20:30]
vpf15_covjk = zeropoint['func_all_cov_3'][:,30:45,30:45]
vpf20_covjk = zeropoint['func_all_cov_4'][:,40:60,40:60]
vpf25_covjk = zeropoint['func_all_cov_5'][:,50:75,50:75]
vpf30_covjk = zeropoint['func_all_cov_6'][:,60:90,60:90]
###
cic10_covjk = zeropoint['func_all_cov_1'][:,21:,21:]
cic15_covjk = zeropoint['func_all_cov_2'][:,30:,30:]
cic25_covjk = zeropoint['func_all_cov_3'][:,45:,45:]
cic40_covjk = zeropoint['func_all_cov_4'][:,60:,60:]
cic55_covjk = zeropoint['func_all_cov_5'][:,75:,75:]
cic70_covjk = zeropoint['func_all_cov_6'][:,90:,90:]

# %%
N_pert = 6000
N_real = 1000

# %%
idx_pert = []
for i in range(N_pert/50):
    idx_pert.append(np.random.choice(np.arange(N_pert),i*50+50,replace=0))

# %%
for i in range(N_pert/50):
    idx_pert[i] = np.concatenate((idx_pert[i],idx_pert[i]+N_pert,idx_pert[i]+2*N_pert,\
                           idx_pert[i]+3*N_pert,idx_pert[i]+4*N_pert,idx_pert[i]+5*N_pert,\
                           idx_pert[i]+6*N_pert))

# %%
idx_0 = []
for i in range(N_real/10):
    idx_0.append(np.random.choice(np.arange(N_real),i*10+10,replace=0))

# %%
p_0 = zeropoint['param'][0]
print p_0
# Out:
# [  1.14385008  13.28584038   0.3484649   11.3075027   11.97185703   0.           0.        ]

# %%
func_0_list = [wp7_0,wp10_0,wp15_0,wp20_0,wp25_0,wp30_0,ds7_0,ds10_0,ds15_0,ds20_0,ds25_0,ds30_0,\
               vpf7_0,vpf10_0,vpf15_0,vpf20_0,vpf25_0,vpf30_0,cic10_0,cic15_0,cic25_0,cic40_0,cic55_0,cic70_0]
func_p_list = [wp7_p,wp10_p,wp15_p,wp20_p,wp25_p,wp30_p,ds7_p,ds10_p,ds15_p,ds20_p,ds25_p,ds30_p,\
               vpf7_p,vpf10_p,vpf15_p,vpf20_p,vpf25_p,vpf30_p,cic10_p,cic15_p,cic25_p,cic40_p,cic55_p,cic70_p]
cov_jk_list = [wp7_covjk,wp10_covjk,wp15_covjk,wp20_covjk,wp25_covjk,wp30_covjk,\
               ds7_covjk,ds10_covjk,ds15_covjk,ds20_covjk,ds25_covjk,ds30_covjk,\
               vpf7_covjk,vpf10_covjk,vpf15_covjk,vpf20_covjk,vpf25_covjk,vpf30_covjk,\
               cic10_covjk,cic15_covjk,cic25_covjk,cic40_covjk,cic55_covjk,cic70_covjk]

# %%
def calc_cov(covjk,func_real):
    return np.mean(covjk,axis=0)+np.cov(func_real.T)

# %%
def df_dp(func0,funcp,paramp):
    dfdp = np.zeros((7,func0.shape[1]))
    for i in range(7):
        for j in range(func0.shape[1]):
            dfdp[i,j] = np.linalg.lstsq((paramp[funcp.shape[0]/7*i:funcp.shape[0]/7*(i+1),i]-p_0[i])[:,np.newaxis],\
                           funcp[funcp.shape[0]/7*i:funcp.shape[0]/7*(i+1),j]-np.mean(func0[:,j],axis=0))[0]
    return dfdp

# %%
def calc_fisher(dfdp, covtot):
    fmatrix = np.zeros((7,7))
    for i in range(7):
        for j in range(7):
            fmatrix[i,j] = np.dot(dfdp[i],np.dot(np.linalg.inv(covtot),dfdp[j]))
    return fmatrix

# %%
def calc_1sigma(fisher):
    return np.sqrt(np.linalg.inv(fisher).diagonal())

# %% [markdown]
# ## Npert test

# %%
wp_Npert_test = []
for i in range(6):
    print i
    wp_Npert_test.append([])
    for j in range(N_pert/50):
        wp_Npert_test[i].append(calc_1sigma(calc_fisher(df_dp(func_0_list[i],func_p_list[i][idx_pert[j]],p_pert[idx_pert[j]]),\
                                                     calc_cov(cov_jk_list[i],func_0_list[i]))))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
wp_Npert_test = np.array(wp_Npert_test)

# %%
for i in range(6):
    for j in range(7):
        plt.figure()
        plt.title('wp{},p{}'.format(i,j))
        plt.plot(np.linspace(50,N_pert,N_pert/50),wp_Npert_test[i,:,j])
        plt.semilogy()
# Out:
# /home/kuw8/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ## Nbin test

# %%
wp_Nbin_test = []
for i in range(6):
    print i
    wp_Nbin_test.append(calc_1sigma(calc_fisher(df_dp(func_0_list[i],func_p_list[i],p_pert),\
                                                     calc_cov(cov_jk_list[i],func_0_list[i]))))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
wp_Nbin_test = np.array(wp_Nbin_test)

# %%
for i in range(7):
    plt.plot([7,10,15,20,25,30],wp_Nbin_test[:,i]/wp_Nbin_test[5,i],'.-',label=str(i))
plt.ylim((0.7,5))
plt.semilogy()
plt.axhline(1,color='k')
plt.legend()

# %%
ds_Nbin_test = []
for i in range(6):
    print i
    ds_Nbin_test.append(calc_1sigma(calc_fisher(df_dp(func_0_list[i+6],func_p_list[i+6],p_pert),\
                                                     calc_cov(cov_jk_list[i+6],func_0_list[i+6]))))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
ds_Nbin_test = np.array(ds_Nbin_test)

# %%
for i in range(7):
    plt.plot([7,10,15,20,25,30],ds_Nbin_test[:,i]/ds_Nbin_test[5,i],'.-',label=str(i))
plt.ylim((0.7,5))
plt.semilogy()
plt.axhline(1,color='k')
plt.legend()

# %%
vpf_Nbin_test = []
for i in range(6):
    print i
    vpf_Nbin_test.append(calc_1sigma(calc_fisher(df_dp(func_0_list[i+12],func_p_list[i+12],p_pert),\
                                                     calc_cov(cov_jk_list[i+12],func_0_list[i+12]))))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
vpf_Nbin_test = np.array(vpf_Nbin_test)

# %%
for i in range(7):
    plt.plot([7,10,15,20,25,30],vpf_Nbin_test[:,i]/vpf_Nbin_test[5,i],'.-',label=str(i))
plt.ylim((0.7,5))
plt.semilogy()
plt.axhline(1,color='k')
plt.legend()

# %%
cic_Nbin_test = []
for i in range(6):
    print i
    cic_Nbin_test.append(calc_1sigma(calc_fisher(df_dp(func_0_list[i+18],func_p_list[i+18],p_pert),\
                                                     calc_cov(cov_jk_list[i+18],func_0_list[i+18]))))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
cic_Nbin_test = np.array(cic_Nbin_test)

# %%
for i in range(7):
    plt.plot([10,15,25,40,55,70],cic_Nbin_test[:,i]/cic_Nbin_test[5,i],'.-',label=str(i))
plt.ylim((0.7,5))
plt.semilogy()
plt.axhline(1,color='k')
plt.legend()
