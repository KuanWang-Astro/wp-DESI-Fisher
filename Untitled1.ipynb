# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.load('Run_051518/fine_bolp_21p0_um_0_b_6986068.npz')

# %%
data.files
# Out:
# ['i', 'func_all', 'param']

# %%
data['func_all'].shape
# Out:
# (1400, 160)

# %%
func_all = data['func_all']
param = data['param']

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+10],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+20],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+30],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+60],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+70],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+90],'.')

# %%
for i in range(10):
    plt.figure()
    plt.plot(param[:200,0],func_all[:200,i+100],'.')
