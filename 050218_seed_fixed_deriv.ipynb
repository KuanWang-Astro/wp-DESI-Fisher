# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
p0_21p0 = np.array((1.33738,13.98811,0.55950,11.95797,12.82356,0.,0.))
Npert = 200

# %%
run_1 = np.load('Run_050218/bolp_21p0_um_0_1165274.npz')
run_2 = np.load('Run_050218/bolp_21p0_um_0_1397530.npz')
run_3 = np.load('Run_050218/bolp_21p0_um_0_2803196.npz')
run_4 = np.load('Run_050218/bolp_21p0_um_0_3616587.npz')
run_5 = np.load('Run_050218/bolp_21p0_um_0_443710.npz')
run_6 = np.load('Run_050218/bolp_21p0_um_0_5211898.npz')
run_7 = np.load('Run_050218/bolp_21p0_um_0_7220757.npz')
run_8 = np.load('Run_050218/bolp_21p0_um_0_7842896.npz')
run_9 = np.load('Run_050218/bolp_21p0_um_0_864081.npz')
run_10 = np.load('Run_050218/bolp_21p0_um_0_9620473.npz')

# %%
def plot_fp(param,func,ip,jf,krun,folder):
    plt.figure()
    plt.plot(param,func,'b.')
    plt.axvline(p0_21p0[ip],linestyle=':',color='grey')
    plt.savefig(folder+'/run{}_p{}f{}'.format(krun,ip,jf))
    plt.close()

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_1['param'][i*Npert:i*Npert+Npert,i],run_1['func_all'][i*Npert:i*Npert+Npert,j],i,j,1,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
plt.plot(run_1['param'][:200,0],run_1['func_all'][0:200,0],'.')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_2['param'][i*Npert:i*Npert+Npert,i],run_2['func_all'][i*Npert:i*Npert+Npert,j],i,j,2,\
               'Run_050218/bolp21p0_um_0_more_bins')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-77520428c8c4> in <module>()
#       1 for i in range(7):
#       2     for j in range(120):
# ----> 3         plot_fp(run_2['param'][i*Npert:i*Npert+Npert,i],run_2['func_all'][i*Npert:i*Npert+Npert,j],i,j,2,               'Run_050218/bolp21p0_um_0_more_bins')
#
# <ipython-input-4-154b6a4febcf> in plot_fp(param, func, ip, jf, krun, folder)
#       1 def plot_fp(param,func,ip,jf,krun,folder):
#       2     plt.figure()
# ----> 3     plt.plot(param,func,'b.')
#       4     plt.axvline(p0_21p0[ip],linestyle=':',color='grey')
#       5     plt.savefig(folder+'/run{}_p{}f{}'.format(krun,ip,jf))
#
# /home/kuw8/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3305 @_autogen_docstring(Axes.plot)
#    3306 def plot(*args, **kwargs):
# -> 3307     ax = gca()
# ...

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_3['param'][i*Npert:i*Npert+Npert,i],run_3['func_all'][i*Npert:i*Npert+Npert,j],i,j,3,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_4['param'][i*Npert:i*Npert+Npert,i],run_4['func_all'][i*Npert:i*Npert+Npert,j],i,j,4,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_5['param'][i*Npert:i*Npert+Npert,i],run_5['func_all'][i*Npert:i*Npert+Npert,j],i,j,5,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_6['param'][i*Npert:i*Npert+Npert,i],run_6['func_all'][i*Npert:i*Npert+Npert,j],i,j,6,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_7['param'][i*Npert:i*Npert+Npert,i],run_7['func_all'][i*Npert:i*Npert+Npert,j],i,j,7,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_8['param'][i*Npert:i*Npert+Npert,i],run_8['func_all'][i*Npert:i*Npert+Npert,j],i,j,8,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_9['param'][i*Npert:i*Npert+Npert,i],run_9['func_all'][i*Npert:i*Npert+Npert,j],i,j,9,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
for i in range(7):
    for j in range(120):
        plot_fp(run_10['param'][i*Npert:i*Npert+Npert,i],run_10['func_all'][i*Npert:i*Npert+Npert,j],i,j,10,\
               'Run_050218/bolp21p0_um_0_more_bins')

# %%
polydfdp_1 = np.zeros((7,120))
polydfdp_2 = np.zeros((7,120))
polydfdp_3 = np.zeros((7,120))
polydfdp_4 = np.zeros((7,120))
polydfdp_5 = np.zeros((7,120))
polydfdp_6 = np.zeros((7,120))
polydfdp_7 = np.zeros((7,120))
polydfdp_8 = np.zeros((7,120))
polydfdp_9 = np.zeros((7,120))
polydfdp_10 = np.zeros((7,120))

# %%
for i in range(7):
    p0 = p0_21p0[i]
    for j in range(120):
####????????????wrong
        a,b,c,d = np.polyfit(run_1['param'][i*Npert:i*Npert+Npert,i],\
                                 run_1['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_1[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_2['param'][i*Npert:i*Npert+Npert,i],\
                                 run_2['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_2[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_3['param'][i*Npert:i*Npert+Npert,i],\
                                 run_3['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_3[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_4['param'][i*Npert:i*Npert+Npert,i],\
                                 run_4['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_4[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_5['param'][i*Npert:i*Npert+Npert,i],\
                                 run_5['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_5[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_6['param'][i*Npert:i*Npert+Npert,i],\
                                 run_6['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_6[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_7['param'][i*Npert:i*Npert+Npert,i],\
                                 run_7['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_7[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_8['param'][i*Npert:i*Npert+Npert,i],\
                                 run_8['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_8[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_9['param'][i*Npert:i*Npert+Npert,i],\
                                 run_9['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_9[i,j] = 3.*a*p0**2+2.*b*p0+c
        a,b,c,d = np.polyfit(run_10['param'][i*Npert:i*Npert+Npert,i],\
                                 run_10['func_all'][i*Npert:i*Npert+Npert,j],3)
        polydfdp_10[i,j] = 3.*a*p0**2+2.*b*p0+c

# %%
polydfdp_mean = (polydfdp_1+polydfdp_2+polydfdp_3+polydfdp_4+polydfdp_5\
                +polydfdp_6+polydfdp_7+polydfdp_8+polydfdp_9+polydfdp_10)/10.

# %%
plt.figure()
plt.imshow((polydfdp_1/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_2/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_3/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_4/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_5/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_6/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_7/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_8/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_9/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')
plt.figure()
plt.imshow((polydfdp_10/polydfdp_mean)[:,:],vmin=-1,vmax=3,cmap='bwr')

# %%
fid_21p0 = np.load('Run_040118/bolp_21p0_0.npz')

# %%
def calc_cov(covjk,func_real):
    return np.mean(covjk,axis=0)+np.cov(func_real.T)

# %%
cov = calc_cov(fid_21p0['func_all_cov'][:,:100,:100],fid_21p0['func_all'][:,:100])

# %%
def calc_fisher(dfdp, covtot):
    fmatrix = np.zeros((7,7))
    for i in range(7):
        for j in range(7):
            fmatrix[i,j] = np.dot(dfdp[i],np.dot(np.linalg.inv(covtot),dfdp[j]))
    return fmatrix

# %%
def calc_1sigma(fisher):
    return np.sqrt(np.linalg.inv(fisher).diagonal())

# %%
def calc_1sigma_prior(fisher,i,priors2):
    fisher1 = fisher*1.
    fisher1[i,i] += priors2
    return np.sqrt(np.linalg.inv(fisher1).diagonal())

# %%
fisher1 = calc_fisher(polydfdp_1[:,:100],cov)
fisher2 = calc_fisher(polydfdp_2[:,:100],cov)
fisher3 = calc_fisher(polydfdp_3[:,:100],cov)
fisher4 = calc_fisher(polydfdp_4[:,:100],cov)
fisher5 = calc_fisher(polydfdp_5[:,:100],cov)
fisher6 = calc_fisher(polydfdp_6[:,:100],cov)
fisher7 = calc_fisher(polydfdp_7[:,:100],cov)
fisher8 = calc_fisher(polydfdp_8[:,:100],cov)
fisher9 = calc_fisher(polydfdp_9[:,:100],cov)
fisher10 = calc_fisher(polydfdp_10[:,:100],cov)

# %%
print calc_1sigma(fisher1)
print calc_1sigma(fisher2)
print calc_1sigma(fisher3)
print calc_1sigma(fisher4)
print calc_1sigma(fisher5)
print calc_1sigma(fisher6)
print calc_1sigma(fisher7)
print calc_1sigma(fisher8)
print calc_1sigma(fisher9)
print calc_1sigma(fisher10)
# Out:
# [ 0.03612871  0.01645215  0.02784181  0.32606574  0.01903818  0.12300061
#   0.19473067]
# [ 0.0317271   0.01615388  0.02689756  0.31506381  0.0179169   0.13902192
#   0.25479886]
# [ 0.03354353  0.01817364  0.03044278  0.3392955   0.02088776  0.15157047
#   0.20023083]
# [ 0.03273681  0.01735408  0.02904483  0.32815497  0.01961113  0.14438
#   0.23068029]
# [ 0.04583759  0.01795698  0.03199416  0.4067675   0.02054211  0.12582971
#   0.20243257]
# [ 0.02717474  0.01597361  0.02726159  0.28394745  0.01839592  0.15226611
#   0.18322324]
# [ 0.03459523  0.01675654  0.02807749  0.28528246  0.01906707  0.15088633
#   0.19003082]
# [ 0.03349853  0.01890181  0.02893016  0.30149958  0.01934257  0.14500766
#   0.26948493]
# [ 0.0311037   0.01631462  0.0257746   0.26067427  0.01777919  0.14049768
#   0.16754798]
# [ 0.03480469  0.01762074  0.0277358   0.31035401  0.01879091  0.15540778
#   0.19888569]

# %%
print calc_1sigma_prior(fisher1,3,100)
print calc_1sigma_prior(fisher2,3,100)
print calc_1sigma_prior(fisher3,3,100)
print calc_1sigma_prior(fisher4,3,100)
print calc_1sigma_prior(fisher5,3,100)
print calc_1sigma_prior(fisher6,3,100)
print calc_1sigma_prior(fisher7,3,100)
print calc_1sigma_prior(fisher8,3,100)
print calc_1sigma_prior(fisher9,3,100)
print calc_1sigma_prior(fisher10,3,100)
# Out:
# [ 0.0294648   0.01583058  0.02781891  0.09560489  0.01873775  0.1229995
#   0.19408608]
# [ 0.02818973  0.01505579  0.02682153  0.09531419  0.01784478  0.13872075
#   0.25289145]
# [ 0.03142766  0.01724907  0.03032429  0.09592068  0.02084207  0.15156992
#   0.19317089]
# [ 0.0322399   0.01502055  0.02903239  0.09565709  0.01940006  0.14424368
#   0.22864199]
# [ 0.03895573  0.01667174  0.03110173  0.09710854  0.02049716  0.12565732
#   0.20229142]
# [ 0.02619398  0.01531086  0.02724721  0.09432161  0.01817218  0.15187501
#   0.18148256]
# [ 0.03213974  0.01551392  0.02805153  0.09437024  0.01899152  0.14878879
#   0.18957132]
# [ 0.03288829  0.01615984  0.02890344  0.09491543  0.01931699  0.14495407
#   0.2668741 ]
# [ 0.02799157  0.01548497  0.02577225  0.09336565  0.01763188  0.14048365
#   0.16754729]
# [ 0.03283791  0.01561274  0.02746947  0.09518109  0.01879025  0.15259243
#   0.19734967]

# %%
print (calc_1sigma(fisher1)+calc_1sigma(fisher2)+calc_1sigma(fisher3)+calc_1sigma(fisher4)+calc_1sigma(fisher5)+\
       calc_1sigma(fisher6)+calc_1sigma(fisher7)+calc_1sigma(fisher8)+calc_1sigma(fisher9)+calc_1sigma(fisher10))/10.
# Out:
# [ 0.03411506  0.01716581  0.02840008  0.31571053  0.01913717  0.14278683
#   0.20920459]

# %%
print (calc_1sigma_prior(fisher1,3,100)+calc_1sigma_prior(fisher2,3,100)+calc_1sigma_prior(fisher3,3,100)+\
       calc_1sigma_prior(fisher4,3,100)+calc_1sigma_prior(fisher5,3,100)+\
       calc_1sigma_prior(fisher6,3,100)+calc_1sigma_prior(fisher7,3,100)+calc_1sigma_prior(fisher8,3,100)+\
       calc_1sigma_prior(fisher9,3,100)+calc_1sigma_prior(fisher10,3,100))/10.
# Out:
# [ 0.03123293  0.01579101  0.02825428  0.09517594  0.01902246  0.14218851
#   0.20739068]

# %%
print (calc_1sigma((fisher1+fisher2+fisher3+fisher4+fisher5+\
                   fisher6+fisher7+fisher8+fisher9+fisher10)/10.))
# Out:
# [ 0.03209476  0.01662304  0.027752    0.29818333  0.01872818  0.13866176
#   0.19744404]

# %%
print (calc_1sigma_prior((fisher1+fisher2+fisher3+fisher4+fisher5+\
                   fisher6+fisher7+fisher8+fisher9+fisher10)/10.,3,100))
# Out:
# [ 0.02989373  0.015463    0.02772941  0.09481041  0.01865191  0.13860995
#   0.19734246]

# %%
calc_1sigma(calc_fisher(polydfdp_mean[:,:100],cov))
# Out:
# array([ 0.09219881,  0.02747477,  0.03474107,  0.91177568,  0.02304521,
#         0.24597947,  0.34108835])

# %%
polydfdp_1
# Out:
# array([[ -5.22314601e-05,   2.63823213e+02,   4.98516703e+02,
#           1.78736473e+02,   3.21926738e+02,   2.64461814e+02,
#           3.38417236e+02,   3.71958729e+02,   3.27678768e+02,
#           3.14925454e+02,   2.53301640e+02,   2.11757745e+02,
#           1.60601228e+02,   1.08770231e+02,   7.89636549e+01,
#           4.40916152e+01,   1.50098348e+01,  -3.51709027e+00,
#          -9.24476288e+00,   1.16745991e+00,  -2.63876479e-01,
#          -2.24475796e+00,  -5.76990401e+00,   4.24622234e+00,
#          -1.01618838e+00,   1.62324285e-02,   2.17383226e+00,
#           1.26778429e+00,   2.40890169e+00,   5.80717826e-01,
#           6.52627324e+00,   4.85781746e+00,   5.11296915e+00,
#           3.61363030e+00,   1.64211986e+00,   2.87378370e+00,
#           1.76496583e+00,   3.04317310e+00,   3.25746063e+00,
#           1.49594298e+00,   2.40148236e+00,   2.37379399e+00,
#           2.89918270e+00,   2.99576557e+00,   3.11337581e+00,
# ...

# %%
polydfdp_mean
# Out:
# array([[ -7.31100062e-05,   2.06158751e+02,   2.15309690e+02,
#           4.38449918e+02,   3.47088976e+02,   3.31157712e+02,
#           2.92692174e+02,   2.72854927e+02,   2.58704491e+02,
#           2.36186169e+02,   1.86341585e+02,   1.59156522e+02,
#           1.22233865e+02,   8.08437813e+01,   5.46719228e+01,
#           2.94913271e+01,   1.53865442e+01,   6.23671355e+00,
#           6.80410214e+00,   6.92158258e+00,   3.94476560e+00,
#           3.72518885e+00,   4.00472215e+00,   4.74657284e+00,
#           3.32441906e+00,   3.72644340e+00,   2.95898122e+00,
#           1.87753744e+00,   2.30400182e+00,   1.55524182e+00,
#           2.87815866e+00,   2.88765998e+00,   2.31025093e+00,
#           3.46744703e+00,   2.37792288e+00,   2.91714545e+00,
#           3.03270485e+00,   2.28742802e+00,   2.61084362e+00,
#           2.27393713e+00,   2.72944418e+00,   2.52966016e+00,
#           2.46875872e+00,   2.69607036e+00,   2.49294083e+00,
# ...

# %%
plt.imshow(np.log10(np.abs(np.linalg.inv(cov))))
plt.colorbar()

# %%
cov_half = calc_cov(fid_21p0['func_all_cov'][::2,:100,:100],fid_21p0['func_all'][::2,:100])

# %%
plt.imshow(np.log10(np.abs(np.linalg.inv(cov_half))))
plt.colorbar()

# %%
plt.imshow(np.log10(np.abs(np.linalg.inv(cov_half)/np.linalg.inv(cov))),cmap='bwr')
plt.colorbar()

# %%
plt.imshow(np.log10(np.abs((cov))))
plt.colorbar()
