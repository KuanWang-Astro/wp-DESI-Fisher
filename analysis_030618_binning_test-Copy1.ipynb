# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import process_fisher as pf

# %% [markdown]
# r_wp = (r_wp[:-1]+r_wp[1:])/2.
#
# r_ds = np.sqrt(0.5*(r_ds[:-1]**2 + r_ds[1:]**2))

# %%
reload(pf)
# Out:
# <module 'process_fisher' from 'process_fisher.pyc'>

# %%
zeropoint = np.load('Run_030618/bolp_19p0_0_bt.npz')

pert = np.load('Run_030618/bolp_19p0_um_0_bt2.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([10,15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [  0.09609048   0.17057175  10.70390092  13.08850909   4.87578299
#   10.03390259   1.32027855]
# 10 [ 0.05542014  0.07012227  1.05445277  3.09212297  0.56787541  0.96852224
#   0.69254292]
# 15 [ 0.02153753  0.02291549  0.17779662  0.58517779  0.09281841  0.29163924
#   0.29602858]
# 20 [ 0.02211178  0.02544174  0.11075806  0.46307217  0.06229097  0.24367212
#   0.22689203]
# 25 [ 0.02087133  0.02427968  0.10482554  0.37345462  0.05589031  0.1778354
#   0.21103255]
# delta sigma
# 7 [  1.78538829   4.02628579  11.15328676  47.67805967   4.47111411
#    7.64461141  13.97637672]
# 10 [ 0.11129593  0.17134363  0.50698267  1.15898946  0.22491972  0.48133262
#   0.97895711]
# 15 [ 0.05883229  0.09169765  0.14206096  0.72944769  0.08049166  0.2726498
#   0.35407165]
# 20 [ 0.05176405  0.07751722  0.11393582  0.80690724  0.06413758  0.20552819
#   0.23273169]
# 25 [ 0.05962977  0.08852304  0.10900502  0.52671272  0.05709795  0.20461449
#   0.21887452]
# vpf
# 7 [ 1.50839991  2.01874983  0.25354008  1.72346042  0.68263125  7.10578238
#   7.55668185]
# 10 [ 0.19285306  0.28136287  0.06363173  0.36710523  0.08897272  1.07719208
#   1.09651345]
# 15 [ 0.1145692   0.12847044  0.06708605  0.45485173  0.06053538  0.38131881
#   0.25581354]
# 20 [ 0.09358399  0.08539773  0.05347735  0.31758366  0.03822273  0.22739222
#   0.20301094]
# 25 [ 0.08497002  0.08831426  0.04809613  0.30718575  0.03335505  0.22302331
#   0.19036297]
# cic
# 10 [ 1.50839991  2.01874983  0.25354008  1.72346042  0.68263125  7.10578238
#   7.55668185]
# 15 [ 0.04342014  0.06864261  0.20364861  0.73461483  0.07746878  0.41178288
#   0.25753378]
# 25 [ 0.02418946  0.03672981  0.08461629  0.28804177  0.04219541  0.13800132
#   0.14559211]
# 40 [ 0.01861592  0.02824316  0.05437612  0.16586609  0.02600443  0.08805754
#   0.0988217 ]
# 70 [ 0.01627184  0.02493348  0.03205513  0.11777753  0.01720307  0.06016092
#   0.06392476]

# %%
dwp_dp_20
# Out:
# array([[  1.55689455e-03,   1.14475655e+03,   1.06522555e+03,
#           9.14164307e+02,   7.45044086e+02,   5.80613193e+02,
#           4.27579533e+02,   2.91209969e+02,   1.77694020e+02,
#           1.02068786e+02,   5.58292929e+01,   3.34769346e+01,
#           2.41025454e+01,   1.85028183e+01,   1.43298029e+01,
#           1.17527526e+01,   8.38607041e+00,   5.79984445e+00,
#           4.38332670e+00,   1.66407549e+00],
#        [ -1.31585382e-02,  -8.29592593e+02,  -6.89120983e+02,
#          -5.44922161e+02,  -4.12938227e+02,  -3.05977665e+02,
#          -2.11508246e+02,  -1.36147112e+02,  -8.16622946e+01,
#          -4.56970330e+01,  -2.61822610e+01,  -1.70731951e+01,
#          -1.32513227e+01,  -1.08047543e+01,  -8.21576795e+00,
#          -6.52587518e+00,  -4.82975150e+00,  -3.50638339e+00,
#          -2.51416534e+00,  -9.74996896e-01],
#        [  1.07654046e-02,  -4.59937359e+02,  -3.25668597e+02,
#          -2.62799864e+02,  -1.90300600e+02,  -1.42067411e+02,
#          -1.01998283e+02,  -6.78552251e+01,  -4.27675306e+01,
#          -2.79758060e+01,  -1.64388088e+01,  -1.38959870e+01,
#          -1.01792458e+01,  -7.83323377e+00,  -6.89345388e+00,
#          -4.92946103e+00,  -3.69787670e+00,  -2.69231355e+00,
#          -1.98699555e+00,  -1.37341982e-01],
#        [ -3.87316919e-04,   1.37835409e+01,   1.15925582e+01,
#           9.20732401e+00,   5.88213049e+00,   4.51025421e+00,
#           8.51391500e-01,  -1.61658014e-01,   7.70610751e-02,
#           4.19311784e-01,   1.46289555e-01,   3.72053236e-02,
#           1.77559681e-01,   4.45297922e-01,   3.95864626e-01,
#           3.09257651e-01,   2.29776001e-01,   2.42362451e-01,
#           2.42098366e-02,   9.24462161e-02],
#        [ -2.31174491e-02,   9.21550039e+02,   7.23647790e+02,
#           5.38409451e+02,   4.00176802e+02,   2.91021673e+02,
#           1.99675097e+02,   1.31476404e+02,   7.83719567e+01,
#           4.94201900e+01,   3.15731546e+01,   2.24263354e+01,
#           1.69366763e+01,   1.37514767e+01,   1.13347638e+01,
#           8.26185438e+00,   5.70443757e+00,   3.78404499e+00,
#           3.20795029e+00,   1.11645860e+00],
#        [  6.53159914e-05,   3.51741856e+00,  -9.29189960e+00,
#           3.94591332e+00,   5.33850288e+00,   7.99738165e+00,
#           7.84656180e+00,   7.37670898e+00,   6.42047517e+00,
#           5.66994830e+00,   3.21142454e+00,   1.73160000e+00,
#           1.98081419e+00,   2.20482234e+00,   1.71861572e+00,
#           9.73490985e-01,   7.19107426e-01,   4.77034020e-01,
#           1.19338244e-01,   1.64504850e-01],
#        [  1.45432238e-05,   4.58970928e+01,   3.34010986e+01,
#           1.66007193e+01,   1.74346543e+01,   1.15453115e+01,
#           7.14844087e+00,   5.22740337e+00,   5.18816345e+00,
#           4.54997391e+00,   2.61485277e+00,   1.03418453e+00,
#           7.29593440e-01,   2.83535652e-01,  -3.29172052e-01,
#          -2.49704744e-01,  -3.16822438e-01,  -1.03820168e-01,
#          -1.10359332e-02,   7.35160381e-02]])

# %%
zeropoint = np.load('Run_030618/bolp_19p5_0_bt.npz')

pert = np.load('Run_030618/bolp_19p5_um_0_bt2.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][200*i:200*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][200*i:200*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([10,15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [  0.45285221   0.47503599   3.36980628  19.55376963   1.13874487
#    3.7244179    3.06722341]
# 10 [ 0.0570569   0.08672844  0.1957924   1.06393879  0.08784941  0.45573382
#   0.91323087]
# 15 [ 0.03120951  0.04081486  0.14521236  0.57884962  0.06866205  0.26604845
#   0.58709931]
# 20 [ 0.02779479  0.02918052  0.07393049  0.42066299  0.03401067  0.21545453
#   0.27024434]
# 25 [ 0.02534029  0.02341124  0.06936207  0.36048147  0.03284365  0.1986626
#   0.17513419]
# delta sigma
# 7 [  0.68841053   2.52282597  11.29916636  70.07120277   6.99578584
#    7.40365727  18.02110797]
# 10 [ 0.50670107  0.4078637   0.77205724  6.57985647  0.78187918  1.94539927
#   1.63216388]
# 15 [ 0.07342322  0.08525898  0.13138754  0.76797437  0.11205455  0.2326195
#   0.22646643]
# 20 [ 0.0661908   0.07682243  0.10008746  0.60741925  0.08228759  0.14930158
#   0.2118603 ]
# 25 [ 0.05093506  0.07845872  0.09023176  0.47172276  0.06834341  0.16292753
#   0.16140283]
# vpf
# 7 [ 0.60369455  0.8764694   0.6168045   1.68604698  0.46395171  0.34167363
#   1.66861868]
# 10 [ 0.1455015   0.1740972   0.07521275  0.50377125  0.05981379  0.33998536
#   0.2534622 ]
# 15 [ 0.13762083  0.12701363  0.0604229   0.43415507  0.04956609  0.19273022
#   0.18700017]
# 20 [ 0.12285175  0.09694647  0.04750113  0.300669    0.03445238  0.14372178
#   0.16778262]
# 25 [ 0.08602277  0.09159918  0.04787357  0.25467203  0.03187427  0.12176234
#   0.15966506]
# cic
# 10 [ 0.60369455  0.8764694   0.6168045   1.68604698  0.46395171  0.34167363
#   1.66861868]
# 15 [ 0.05325158  0.0794884   0.18991619  0.90873476  0.07906204  0.29825912
#   0.43400262]
# 25 [ 0.02560536  0.03227119  0.05821785  0.25514286  0.02275485  0.09239823
#   0.14028419]
# 40 [ 0.02314838  0.02979349  0.04200587  0.1794325   0.01985887  0.08111908
#   0.0787024 ]
# 70 [ 0.01882793  0.02545759  0.02920092  0.1226127   0.01577447  0.05867358
#   0.0583978 ]
