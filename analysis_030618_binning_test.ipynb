# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import process_fisher as pf

# %% [markdown]
# r_wp = (r_wp[:-1]+r_wp[1:])/2.
#
# r_ds = np.sqrt(0.5*(r_ds[:-1]**2 + r_ds[1:]**2))

# %%
reload(pf)
# Out:
# <module 'process_fisher' from 'process_fisher.pyc'>

# %%
zeropoint = np.load('Run_030618/bolp_19p0_0_bt.npz')

pert = np.load('Run_030618/bolp_19p0_um_0_bt.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([10,15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [ 0.14184003  0.20595981  1.00944573  7.59400043  0.65176607  2.33630912
#   3.32869654]
# 10 [ 0.05439165  0.08113232  0.38339224  2.26498852  0.13483533  0.24710728
#   0.74558618]
# 15 [ 0.02808151  0.04709971  0.10173539  0.75874306  0.04370335  0.14262567
#   0.36225424]
# 20 [ 0.01824307  0.02409933  0.07518668  0.44721184  0.03504342  0.14579534
#   0.14382162]
# 25 [ 0.01735565  0.0217921   0.05656123  0.34349027  0.02595679  0.11479034
#   0.10301979]
# delta sigma
# 7 [ 0.11803732  0.3143372   1.67053557  5.26591013  0.89743373  1.7730826
#   1.96605562]
# 10 [ 0.08117007  0.10079658  0.13481605  1.37082696  0.17264334  1.28071862
#   0.79957378]
# 15 [ 0.04517272  0.06135955  0.10689812  0.57517339  0.05493916  0.19147671
#   0.29564093]
# 20 [ 0.03849869  0.05733399  0.06377256  0.39237737  0.03938527  0.2337959
#   0.16412112]
# 25 [ 0.0418572   0.05605175  0.04688732  0.37960738  0.0339291   0.14080339
#   0.13425536]
# vpf
# ...

# %%
dwp_dp_20
# Out:
# array([[  1.34308021e-03,   1.21084374e+03,   1.07353312e+03,
#           9.56496534e+02,   7.71082288e+02,   5.99947914e+02,
#           4.41696772e+02,   3.01834930e+02,   1.88774370e+02,
#           1.07148103e+02,   6.10874434e+01,   3.37027287e+01,
#           2.51938971e+01,   1.89399115e+01,   1.46961220e+01,
#           1.27135959e+01,   9.65856791e+00,   7.03268832e+00,
#           5.37917061e+00,   1.75622991e+00],
#        [ -1.29527677e-02,  -8.25249376e+02,  -6.61109786e+02,
#          -5.28435473e+02,  -4.03730624e+02,  -2.94658390e+02,
#          -2.12175992e+02,  -1.34782582e+02,  -8.02153088e+01,
#          -4.44656859e+01,  -2.60403718e+01,  -1.71012546e+01,
#          -1.35113035e+01,  -1.10487501e+01,  -8.75880901e+00,
#          -7.38865053e+00,  -5.20475058e+00,  -3.44967190e+00,
#          -2.20212027e+00,  -8.36153938e-01],
#        [  1.08875273e-02,  -4.22967645e+02,  -3.67877859e+02,
#          -2.51346984e+02,  -1.85605045e+02,  -1.35630160e+02,
# ...

# %%
zeropoint = np.load('Run_030618/bolp_19p5_0_bt.npz')

pert = np.load('Run_030618/bolp_19p5_um_0_bt.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([10,15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [  1.38131838   1.23488146   7.59787007  48.55988217   1.06326194
#   51.22515826  35.3578199 ]
# 10 [ 0.06323315  0.03628887  0.14006943  1.13179964  0.08045885  1.02805383
#   0.67189275]
# 15 [ 0.03085244  0.02040202  0.10671283  0.61028498  0.04460757  0.16837303
#   0.24276902]
# 20 [ 0.0228345   0.01787586  0.05480991  0.36018869  0.02251213  0.16610163
#   0.11027642]
# 25 [ 0.02319248  0.01783295  0.04420498  0.29124378  0.01806058  0.15684054
#   0.09873544]
# delta sigma
# 7 [ 0.40722367  0.93881968  1.36069664  3.57227088  0.87148071  2.75979133
#   0.80424421]
# 10 [ 0.17337279  0.3370208   0.38255114  1.05151103  0.24776018  0.5763285
#   0.5640071 ]
# 15 [ 0.11546786  0.16899311  0.12172118  0.5491672   0.09308085  0.33755401
#   0.40753342]
# 20 [ 0.08771763  0.12328205  0.08943     0.43184984  0.06802904  0.22963366
#   0.25972862]
# 25 [ 0.05103253  0.06555807  0.08022476  0.33236384  0.04652504  0.21571929
#   0.17307139]
# vpf
# ...

# %%
zeropoint = np.load('Run_030618/bolp_20p0_0_bt.npz')

pert = np.load('Run_030618/bolp_20p0_um_0_bt.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([10,15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [ 0.20351982  0.08814732  1.38923813  9.81594825  0.62943409  3.14863388
#   2.32742346]
# 10 [ 0.05609301  0.05562855  0.26764766  3.92861684  0.15945203  0.68118505
#   2.07457644]
# 15 [ 0.0385009   0.02765012  0.12580682  0.5362902   0.04243236  0.37775178
#   0.16966495]
# 20 [ 0.02695718  0.01798233  0.06169774  0.24757708  0.02535933  0.1554441
#   0.10712724]
# 25 [ 0.02396737  0.01724943  0.04753067  0.22588211  0.02187248  0.14631656
#   0.08762158]
# delta sigma
# 7 [  0.17185687   0.34955208   0.45119923  15.72886543   0.64300279
#    1.40513045   1.49435799]
# 10 [ 0.08243086  0.11273611  0.22907848  1.23959143  0.16672893  0.82467638
#   0.71282104]
# 15 [ 0.08163302  0.08589058  0.13052607  0.50747807  0.06790466  0.19875574
#   0.30691043]
# 20 [ 0.05385462  0.05432225  0.07868316  0.35597035  0.05376002  0.25170073
#   0.15743817]
# 25 [ 0.04774993  0.04930437  0.08669068  0.39707237  0.06139538  0.25226446
#   0.17117256]
# vpf
# ...

# %%
zeropoint = np.load('Run_030618/bolp_20p5_0_bt.npz')

pert = np.load('Run_030618/bolp_20p5_um_0_bt.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([10,15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [  1.18021001   0.50752078   3.47062521  66.42253378   0.49391281
#    4.15397399   2.37636066]
# 10 [ 0.04811865  0.03676864  0.11738266  1.61159261  0.03195256  0.47934195
#   0.30630203]
# 15 [ 0.04814441  0.01852356  0.08327555  0.62600751  0.02036278  0.29173403
#   0.21557503]
# 20 [ 0.03928335  0.01948188  0.05828548  0.64456566  0.01778909  0.17797846
#   0.15393698]
# 25 [ 0.03097817  0.01725749  0.07197694  0.34953245  0.02021872  0.14828655
#   0.11059414]
# delta sigma
# 7 [ 1.03291744  0.22886657  0.86762012  3.58025268  0.09855495  8.09977979
#   2.37590883]
# 10 [ 0.11188193  0.0524888   0.19056985  0.99828149  0.04067348  0.69092344
#   0.24229429]
# 15 [ 0.06508661  0.05292583  0.14893976  0.46663164  0.04089541  0.70931656
#   0.23116626]
# 20 [ 0.06750062  0.0464      0.06826206  0.39694155  0.02533209  0.26283966
#   0.16105819]
# 25 [ 0.05068822  0.0357619   0.05861912  0.29506531  0.02319965  0.18289144
#   0.14217525]
# vpf
# ...

# %%
zeropoint = np.load('Run_030618/bolp_21p0_0_bt.npz')

pert = np.load('Run_030618/bolp_21p0_um_0_bt.npz')

# %%
print 'ng+wp'

sigma_wp = []

wp_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,:7,:7],axis=0)+np.cov(zeropoint['func_all_2'][:,:7].T)

dwp_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        dwp_dp_7[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dwp_dp_7[i],np.dot(np.linalg.inv(wp_cov_7),dwp_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

wp_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,:10,:10],axis=0)+np.cov(zeropoint['func_all_3'][:,:10].T)

dwp_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10):
        dwp_dp_10[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dwp_dp_10[i],np.dot(np.linalg.inv(wp_cov_10),dwp_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

wp_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,:15,:15],axis=0)+np.cov(zeropoint['func_all_4'][:,:15].T)

dwp_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15):
        dwp_dp_15[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dwp_dp_15[i],np.dot(np.linalg.inv(wp_cov_15),dwp_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

wp_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,:20,:20],axis=0)+np.cov(zeropoint['func_all_5'][:,:20].T)

dwp_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20):
        dwp_dp_20[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dwp_dp_20[i],np.dot(np.linalg.inv(wp_cov_20),dwp_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

wp_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,:25,:25],axis=0)+np.cov(zeropoint['func_all_6'][:,:25].T)

dwp_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25):
        dwp_dp_25[i,j] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dwp_dp_25[i],np.dot(np.linalg.inv(wp_cov_25),dwp_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_wp.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_wp = np.array(sigma_wp)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_wp[:,i]/sigma_wp[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'delta sigma'

sigma_ds = []

ds_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,7:14,7:14],axis=0)+np.cov(zeropoint['func_all_2'][:,7:14].T)

dds_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7,14):
        dds_dp_7[i,j-7] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dds_dp_7[i],np.dot(np.linalg.inv(ds_cov_7),dds_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

ds_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,10:20,10:20],axis=0)+np.cov(zeropoint['func_all_3'][:,10:20].T)

dds_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(10,20):
        dds_dp_10[i,j-10] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dds_dp_10[i],np.dot(np.linalg.inv(ds_cov_10),dds_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

ds_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,15:30,15:30],axis=0)+np.cov(zeropoint['func_all_4'][:,15:30].T)

dds_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(15,30):
        dds_dp_15[i,j-15] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dds_dp_15[i],np.dot(np.linalg.inv(ds_cov_15),dds_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

ds_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,20:40,20:40],axis=0)+np.cov(zeropoint['func_all_5'][:,20:40].T)

dds_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(20,40):
        dds_dp_20[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dds_dp_20[i],np.dot(np.linalg.inv(ds_cov_20),dds_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

ds_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,25:50,25:50],axis=0)+np.cov(zeropoint['func_all_6'][:,25:50].T)

dds_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(25,50):
        dds_dp_25[i,j-25] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dds_dp_25[i],np.dot(np.linalg.inv(ds_cov_25),dds_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_ds.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_ds = np.array(sigma_ds)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_ds[:,i]/sigma_ds[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'vpf'

sigma_vpf = []

vpf_cov_7 = np.mean(zeropoint['func_all_cov_2'][:,14:21,14:21],axis=0)+np.cov(zeropoint['func_all_2'][:,14:21].T)

dvpf_dp_7 = np.zeros((7,7))
for i in range(7):
    for j in range(14,21):
        dvpf_dp_7[i,j-14] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_7 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_7[i,j] = np.dot(dvpf_dp_7[i],np.dot(np.linalg.inv(vpf_cov_7),dvpf_dp_7[j]))

print 7,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

vpf_cov_10 = np.mean(zeropoint['func_all_cov_3'][:,20:30,20:30],axis=0)+np.cov(zeropoint['func_all_3'][:,20:30].T)

dvpf_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(20,30):
        dvpf_dp_10[i,j-20] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dvpf_dp_10[i],np.dot(np.linalg.inv(vpf_cov_10),dvpf_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

vpf_cov_15 = np.mean(zeropoint['func_all_cov_4'][:,30:45,30:45],axis=0)+np.cov(zeropoint['func_all_4'][:,30:45].T)

dvpf_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dvpf_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dvpf_dp_15[i],np.dot(np.linalg.inv(vpf_cov_15),dvpf_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_15).diagonal())

vpf_cov_20 = np.mean(zeropoint['func_all_cov_5'][:,40:60,40:60],axis=0)+np.cov(zeropoint['func_all_5'][:,40:60].T)

dvpf_dp_20 = np.zeros((7,20))
for i in range(7):
    for j in range(40,60):
        dvpf_dp_20[i,j-40] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_20 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_20[i,j] = np.dot(dvpf_dp_20[i],np.dot(np.linalg.inv(vpf_cov_20),dvpf_dp_20[j]))

print 20,np.sqrt(np.linalg.inv(fmatrix_20).diagonal())

vpf_cov_25 = np.mean(zeropoint['func_all_cov_6'][:,50:75,50:75],axis=0)+np.cov(zeropoint['func_all_6'][:,50:75].T)

dvpf_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(50,75):
        dvpf_dp_25[i,j-50] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dvpf_dp_25[i],np.dot(np.linalg.inv(vpf_cov_25),dvpf_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_7).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_20).diagonal()))
sigma_vpf.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_vpf = np.array(sigma_vpf)
plt.figure()
for i in range(7):
    plt.plot([7,10,15,20,25],sigma_vpf[:,i]/sigma_vpf[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()

print 'cic'

sigma_cic = []

cic_cov_10 = np.mean(zeropoint['func_all_cov_2'][:,21:,21:],axis=0)+np.cov(zeropoint['func_all_2'][:,21:].T)

dcic_dp_10 = np.zeros((7,10))
for i in range(7):
    for j in range(21,31):
        dcic_dp_10[i,j-21] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_2'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_2'][:,j],axis=0))[0]

fmatrix_10 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_10[i,j] = np.dot(dcic_dp_10[i],np.dot(np.linalg.inv(cic_cov_10),dcic_dp_10[j]))

print 10,np.sqrt(np.linalg.inv(fmatrix_7).diagonal())

cic_cov_15 = np.mean(zeropoint['func_all_cov_3'][:,30:,30:],axis=0)+np.cov(zeropoint['func_all_3'][:,30:].T)

dcic_dp_15 = np.zeros((7,15))
for i in range(7):
    for j in range(30,45):
        dcic_dp_15[i,j-30] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_3'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_3'][:,j],axis=0))[0]

fmatrix_15 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_15[i,j] = np.dot(dcic_dp_15[i],np.dot(np.linalg.inv(cic_cov_15),dcic_dp_15[j]))

print 15,np.sqrt(np.linalg.inv(fmatrix_10).diagonal())

cic_cov_25 = np.mean(zeropoint['func_all_cov_4'][:,45:,45:],axis=0)+np.cov(zeropoint['func_all_4'][:,45:].T)

dcic_dp_25 = np.zeros((7,25))
for i in range(7):
    for j in range(45,70):
        dcic_dp_25[i,j-45] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_4'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_4'][:,j],axis=0))[0]

fmatrix_25 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_25[i,j] = np.dot(dcic_dp_25[i],np.dot(np.linalg.inv(cic_cov_25),dcic_dp_25[j]))

print 25,np.sqrt(np.linalg.inv(fmatrix_25).diagonal())

cic_cov_40 = np.mean(zeropoint['func_all_cov_5'][:,60:,60:],axis=0)+np.cov(zeropoint['func_all_5'][:,60:].T)

dcic_dp_40 = np.zeros((7,40))
for i in range(7):
    for j in range(60,100):
        dcic_dp_40[i,j-60] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_5'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_5'][:,j],axis=0))[0]

fmatrix_40 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_40[i,j] = np.dot(dcic_dp_40[i],np.dot(np.linalg.inv(cic_cov_40),dcic_dp_40[j]))

print 40,np.sqrt(np.linalg.inv(fmatrix_40).diagonal())

cic_cov_70 = np.mean(zeropoint['func_all_cov_6'][:,75:,75:],axis=0)+np.cov(zeropoint['func_all_6'][:,75:].T)

dcic_dp_70 = np.zeros((7,70))
for i in range(7):
    for j in range(75,145):
        dcic_dp_70[i,j-75] = np.linalg.lstsq((pert['param'][100*i:100*(i+1),i]-np.mean(zeropoint['param'][:,i]))[:,np.newaxis],\
                    pert['func_all_6'][100*i:100*(i+1),j]-np.mean(zeropoint['func_all_6'][:,j],axis=0))[0]

fmatrix_70 = np.zeros((7,7))
for i in range(7):
    for j in range(7):
        fmatrix_70[i,j] = np.dot(dcic_dp_70[i],np.dot(np.linalg.inv(cic_cov_70),dcic_dp_70[j]))

print 70,np.sqrt(np.linalg.inv(fmatrix_70).diagonal())

sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_10).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_15).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_25).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_40).diagonal()))
sigma_cic.append(np.sqrt(np.linalg.inv(fmatrix_70).diagonal()))
sigma_cic = np.array(sigma_cic)
plt.figure()
for i in range(7):
    plt.plot([15,25,40,70],sigma_cic[:,i]/sigma_cic[4,i],'.-',label='{}'.format(i))
plt.ylim((0.9,3))
plt.legend()
# Out:
# ng+wp
# 7 [ 0.41810906  0.07749347  0.48085233  3.89378284  0.27801351  2.16365336
#   1.29541591]
# 10 [ 0.22652224  0.0354761   0.11014769  0.98577451  0.07075225  0.44271965
#   0.39869095]
# 15 [ 0.1015401   0.02590764  0.07163533  0.55884683  0.04598665  0.31937685
#   0.19966858]
# 20 [ 0.07335454  0.0276766   0.06156849  0.50286643  0.04048523  0.18703631
#   0.10197349]
# 25 [ 0.06038967  0.02513751  0.05146749  0.29533781  0.03496343  0.14157708
#   0.10392339]
# delta sigma
# 7 [ 1.39157621  0.59319053  0.488094    3.58362547  0.24343994  2.27241754
#   0.75633907]
# 10 [ 0.13722955  0.05620874  0.0856599   0.43451773  0.08162979  0.41682822
#   0.25355705]
# 15 [ 0.0795051   0.04922811  0.05926351  0.31004928  0.05185682  0.13864208
#   0.13610232]
# 20 [ 0.06767277  0.04860755  0.04911578  0.21066776  0.0421733   0.14223037
#   0.15166427]
# 25 [ 0.05741326  0.04764996  0.04266297  0.2603547   0.03864347  0.10363969
#   0.12310265]
# vpf
# ...
